# %% [markdown]
# ## Distributed lag model
#
# $$
# y_{t}=a+w_{0}x_{t}+w_{1}x_{t-1}+w_{2}x_{t-2}+...+{\text{error term}}
# $$
#
# https://en.wikipedia.org/wiki/Distributed_lag

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 100
time = np.arange(N+1)
dt = 1
d = 3

x_diff = np.random.normal(size = [N,d]) * np.sqrt(dt)
x = np.cumsum(x_diff,axis = 0)
x = np.concatenate([np.zeros([1,d]), x], axis = 0)

# x1 = 0.5 * np.sqrt(time)[:,None]
# x2 = np.sin(time)[:,None]
# x3 = np.log(time+1)[:,None]
# x = np.concatenate([x1,x2,x3], axis = 1)

plt.plot(time,x)
plt.show()

# %%
def lag(x,length,gap):
    x = x[:,None,:]
    X = x[:1-length-gap]
    for i in range(1,length):
        helper = x[i:1-length-gap+i]
        X = np.concatenate([X, helper], axis = 1)
    return X
x_lag = lag(x,3,1)
len_lag = x_lag.shape[0]

# %%
import torch
import torch.nn as nn
x_lag_flatten = torch.tensor(x_lag, dtype = torch.float).view([len_lag,-1])
linear = nn.Linear(x_lag_flatten.shape[-1],1)
y = linear(x_lag_flatten)
y = y.detach().numpy() + np.random.normal(size = [len_lag,1])
plt.plot(y)
plt.show()

# %%
import sklearn
split = 60
num_sample = x_lag.shape[0]
X = np.reshape(x_lag,[num_sample,-1])
y = y
X_train = X[:split]
y_train = y[:split]
X_test = X[split:]
y_test = y[split:]

# %%
from sklearn.linear_model import Ridge
model = Ridge(alpha=1)
model.fit(X_train, y_train)
y_train_predict = model.predict(X_train)
y_test_predict = model.predict(X_test)
y_predict = np.concatenate([y_train_predict,y_test_predict],axis = 0)

# %%
plt.plot(y)
plt.plot(y_predict)
lmax = max(y.max(),y_predict.max())
lmin = min(y.min(),y_predict.min())
plt.vlines(split,lmin,lmax,'r')
plt.legend(['True', 'Predict', 'train-test split'])
plt.show()

# %%
def lag(x,length,gap):
    x = x[:,None,:]
    X = x[:1-length-gap]
    for i in range(1,length):
        helper = x[i:1-length-gap+i]
        X = np.concatenate([X, helper], axis = 1)
    return X

# %% [markdown]
# ## Real Data

# %% [markdown]
# $$
# d_{t} = f(c_{t-1}, c_{t-2}, c_{t-3}) + noise
# $$
# where $d$ is death and $c$ is new cases

# %%
import pandas as pd
from sklearn import preprocessing
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge

# %%
df = pd.read_csv("data/1_owid/owid-covid-data.csv")
df_europe = df[df['continent'] == 'Europe']
df0 = df_europe
df0 = df0[['date',\
           'location',\
       'new_cases_smoothed_per_million',\
       'new_deaths_smoothed_per_million',\
       'icu_patients_per_million']]
#        'positive_rate']]
df0 =df0.dropna()
df00 = df0

C = list(df0['location'].drop_duplicates())
df00 = df0.drop(columns=['date','location'])
x = df00.values 
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df00 = pd.DataFrame(x_scaled, index = df00.index, columns=df00.columns)

# %%
df_helper = df_europe[['location', 'population','population_density']]
POPULATION = []
POPULATION_DENSITY = []
for c in C:
    population = df_helper[df_helper['location'] == c].iloc[0]['population']
    density = df_helper[df_helper['location'] == c].iloc[0]['population_density']
    POPULATION.append(population)
    POPULATION_DENSITY.append(density)

# %%
C_large = []
POPULATION_large = []
choose_large = []
for c,p in zip(C,POPULATION):
    if p > 10**7:
        C_large.append(c)
        POPULATION_large.append(p)

# %%
DICT = {}
TRAIN = []
TEST = []
RANGE_TRAIN = []
RANGE_TEST = []
for c in C:
    print(c)
    cc = df00[df0['location'] == c]
    x = cc[['new_cases_smoothed_per_million', 'icu_patients_per_million']].values
    y = cc['new_deaths_smoothed_per_million'].values
    length = 5
    gap = 5
    x_lag = lag(x,length,gap)
    y_lag = y[:len(x_lag),None]
    
    num_sample = x_lag.shape[0]
    split = int(0.7*num_sample)
    X = np.reshape(x_lag,[num_sample,-1])
    Y = y_lag
    X_train = X[:split]
    Y_train = Y[:split]
    X_test = X[split:]
    Y_test = Y[split:]
    
    model = Ridge(alpha=1)
    model.fit(X_train, Y_train)
    
    train_score = model.score(X_train,Y_train)
    test_score = model.score(X_test,Y_test)
    print('train', train_score)
    print('test', test_score)
    TRAIN.append(train_score)
    TEST.append(test_score)
    
    DICT[c] = [cc, model, X_train, Y_train, X_test, Y_test, X, Y]
    
    Y_train_predict = model.predict(X_train)
    Y_test_predict = model.predict(X_test)
    Y_predict = np.concatenate([Y_train_predict,Y_test_predict],axis = 0)
    Y_predict_aug = np.concatenate([Y[:length+gap-1,:],Y_predict],axis = 0)
    
    cc = cc.assign(predict_death=pd.Series(Y_predict_aug[:,0]).values)
    
    range_train = [x_lag[:split,:,1].min(),x_lag[:split,:,1].max()]
    range_test = [x_lag[split:,:,1].min(),x_lag[split:,:,1].max()]
    print('range_train: ', range_train)
    print('range_test : ', range_test )
    RANGE_TRAIN.append(range_train )
    RANGE_TEST.append(range_test )
    cc.plot()
    
#     plt.plot(Y)
#     plt.plot(Y_predict)
#     lmax = max(y.max(),Y_predict.max())
#     lmin = min(y.min(),Y_predict.min())
    plt.vlines(cc.index[split],-0.1,1.1,'r')
#     plt.legend(['True', 'Predict', 'train-test split'])
    plt.show()
# Out:
# Austria
# train 0.8713886905300795
# test 0.08428892693968659
# range_train:  [0.005236548909838579, 0.23309719066227405]
# range_test :  [0.0838083706155697, 0.6189663712917607]
# Belgium
# train 0.8119138012750021
# test 0.39229553608553414
# range_train:  [0.015607431810855225, 0.8717753158834121]
# range_test :  [0.08141025137007304, 1.0]
# Cyprus
# train 0.311193093473886
# test 0.037136942488280034
# range_train:  [0.0, 0.1256771738361259]
# range_test :  [0.0, 0.1526068735601456]
# Czechia
# train 0.3924384152269713
# test -1.764506923186647
# range_train:  [0.0, 0.13509667172499468]
# range_test :  [0.09838579055376898, 0.8817923779121424]
# Denmark
# train 0.7010012499968872
# test 0.6914315172450185
# range_train:  [0.0, 0.19818686459668353]
# range_test :  [0.017643867498014675, 0.11809754448314633]
# Estonia
# train 0.3678884727543861
# test 0.5072772496182598
# range_train:  [0.0, 0.11854571758804243]
# range_test :  [0.005928465282309742, 0.19560004088596747]
# Finland
# train 0.2678054114220725
# test -3.2707773277669077
# range_train:  [0.0, 0.117783037041114]
# range_test :  [0.0, 0.04256858227907818]
# France
# train 0.917560265069698
# test 0.7846622954592013
# range_train:  [0.00011794029076213015, 0.8454903564155587]
# range_test :  [0.10046153967118246, 0.5906056627064937]
# Germany
# train 0.9382186897230649
# test 0.7572969851321091
# range_train:  [0.018768231603280314, 0.27477728941761087]
# range_test :  [0.030405006958477157, 0.4881784515226092]
# Iceland
# train 0.5848543425549978
# test -0.06756377530400304
# range_train:  [0.0, 0.32257455792047685]
# range_test :  [0.0, 0.09216640588757931]
# Ireland
# train 0.5826912811594012
# test -17.154552354592624
# range_train:  [0.006368775701155029, 0.2468175778209352]
# range_test :  [0.03184387850577514, 0.07006439539875613]
# Italy
# train 0.9520322906960563
# test 0.8741455038735593
# range_train:  [0.0033809550018477313, 0.5290172428705094]
# range_test :  [0.028871783178569463, 0.5004049283316166]
# Luxembourg
# train 0.8341239229522187
# test 0.46992962089056256
# range_train:  [0.0, 0.43962636515886555]
# range_test :  [0.012564572309192267, 0.6280320483083431]
# Malta
# train 0.02533755248452252
# test -0.014065058023893684
# range_train:  [0.0, 0.08903705683935746]
# range_test :  [0.0, 0.03561796781016331]
# Netherlands
# train 0.9168378155347888
# test 0.8251047265454609
# range_train:  [0.006423814503510689, 0.6057098826100973]
# range_test :  [0.041758725615844886, 0.2808315576767335]
# Portugal
# train 0.760887114068137
# test 0.5925759855646333
# range_train:  [0.0, 0.20896660717234222]
# range_test :  [0.05937114236965632, 0.41330995494680894]
# Romania
# train 0.8749200797443643
# test -0.22202343356883247
# range_train:  [0.002453158047852307, 0.23827870076975696]
# range_test :  [0.2247941941926201, 0.5309200128948052]
# Slovenia
# train 0.6185700040359564
# test -0.5014881645705622
# range_train:  [0.0, 0.13615813434185386]
# range_test :  [0.04916537587570666, 0.8017974100312149]
# Spain
# train 0.6811213457692518
# test -1.931781447914148
# range_train:  [0.08778688975727887, 0.5201481330051972]
# range_test :  [0.32877035452851405, 0.5307391711156366]
# Sweden
# train 0.9763161444890358
# test 0.7441068067026049
# range_train:  [0.009340871028360708, 0.43442912967928105]
# range_test :  [0.015568118380601181, 0.23667471281539199]
# United Kingdom
# train 0.9633585911178535
# test 0.8111990830621727
# range_train:  [0.006950614468914871, 0.38233097190662274]
# range_test :  [0.039494272033211986, 0.17709127792236384]

# %% [markdown]
# # Relation between population and score

# %%
import string
from matplotlib import cm

def plot_scatter_helper(name_x, name_y, x, y, C):
    df_helper = pd.DataFrame({name_x:x, name_y:y}, 
                      index=C)
    fig, ax = plt.subplots(figsize = [12,4])


    cmap = cm.get_cmap('Spectral')
    df_helper.plot(name_x, name_y, kind='scatter', ax=ax, s=100, linewidth=0, 
            c=range(len(df_helper)), colormap=cmap)

    for k, v in df_helper.iterrows():
        ax.annotate(k, v,
                    xytext=(10,-5), textcoords='offset points',
                    family='sans-serif', fontsize=10, color='darkslategrey')
    fig.canvas.draw()

# %%
name_x = 'LogPopulation'
name_y = 'transformed test score'
x = np.log(np.array(POPULATION))
y = np.exp(np.array(TEST)-1)
print('LogPopulation - transformed train score')
plot_scatter_helper(name_x, name_y, x, y, C)

# name_x = 'LogPopulation'
# name_y = 'transformed train score'
# x = np.log(np.array(POPULATION))
# y = np.exp(np.array(TRAIN)-1)
# print('train score')
# plot_scatter_helper(name_x, name_y, x, y)
# Out:
# LogPopulation - transformed train score

# %% [markdown]
# # Relation between peak and score

# %%
def overlap(train, test):
    error1 = train[0] - test[0]
    error1 = (error1 > 0) * error1
    error2 = test[1] - train[1]
    error2 = (error2 > 0) * error2 
    return error1 + error2
DIFF_lap = [overlap(train,test) for train,test in zip(RANGE_TRAIN,RANGE_TEST)]

DIFF = [train[1] - train[0] for train in RANGE_TRAIN]

name_x = 'Suffering from first round'
name_y = 'transformed test score'
x = np.array(DIFF) - np.array(DIFF_lap)
y = np.exp((np.array(TEST)-1))
print('Suffering from first round  - transformed train score')
plot_scatter_helper(name_x, name_y, x, y, C)
# Out:
# Suffering from first round  - transformed train score

# %% [markdown]
# # Use Italy to predict Austria

# %%
_, model, _, _, _, _, _, _ =  DICT['Italy']
cc, model0, X_train, Y_train, X_test, Y_test, X, Y = DICT['Austria']

Y_train_predict = model.predict(X_train)
Y_test_predict = model.predict(X_test)
Y_predict = np.concatenate([Y_train_predict,Y_test_predict],axis = 0)
Y_predict_aug = np.concatenate([Y[:length+gap-1,:],Y_predict],axis = 0)

Y_train_predict0 = model0.predict(X_train)
Y_test_predict0 = model0.predict(X_test)
Y_predict0 = np.concatenate([Y_train_predict0,Y_test_predict0],axis = 0)
Y_predict_aug0 = np.concatenate([Y[:length+gap-1,:],Y_predict0],axis = 0)

cc = cc.assign(predict_death_Italy=pd.Series(Y_predict_aug[:,0]).values)
cc = cc.assign(predict_death_Austria=pd.Series(Y_predict_aug0[:,0]).values)
cc.plot()
#     plt.plot(Y)
#     plt.plot(Y_predict)
#     lmax = max(y.max(),Y_predict.max())
#     lmin = min(y.min(),Y_predict.min())
plt.vlines(cc.index[split],-0.1,1.1,'r')
#     plt.legend(['True', 'Predict', 'train-test split'])
plt.show()

# %%
# df2 = pd.read_csv("data/2_ecdc/notification.csv")
# df2 = pd.read_csv("data/2_ecdc/dailynotificationeu.csv")
# df2 = pd.read_csv("data/2_ecdc/weeklynotificationeu.csv")
# df2 = pd.read_csv("data/2_ecdc/admissionrates.csv")
# df2 = pd.read_csv("data/2_ecdc/country_response_measures.csv")
# df2 = pd.read_csv("data/2_ecdc/agerangenotificationeu.csv")
# df2
